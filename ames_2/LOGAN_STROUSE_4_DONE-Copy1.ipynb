# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('AMES_TRAIN.csv')
test = pd.read_csv('AMES_TEST_SFAM.csv')
train.columns = [s.lower() for s in train.columns]
test.columns = [s.lower() for s in test.columns]
train['qualityindex'] = (train.overallqual*train.overallcond)
train['totalsqftcalc'] = (train.bsmtfinsf1+train.bsmtfinsf2+train.grlivarea)
train['pricesqfoot'] = (train['saleprice']/train['totalsqftcalc'])
test['qualityindex'] = (test.overallqual*test.overallcond)
test['totalsqftcalc'] = (test.bsmtfinsf1+test.bsmtfinsf2+test.grlivarea)
test['pricesqfoot'] = (test['saleprice']/test['totalsqftcalc'])
train=train.replace({'totalsqftcalc': {np.NaN : 10000}})
train=train.replace({'lotarea': {np.NaN : 10000}})
train=train.replace({'lotfrontage': {np.NaN : 10000}})
test=test.replace({'totalsqftcalc': {np.NaN : 10000}})
test=test.replace({'lotarea': {np.NaN : 10000}})
test=test.replace({'lotfrontage': {np.NaN : 10000}})

# %%
test['Neighborhood_Group'] = np.nan
#added due to later work with Neighborhood groupings

# %%
train = train[train['totalsqftcalc'] < 6000]
train = train[train['salecondition'] == 'Normal']
train = train[train['saleprice'] <= 500000]
train = train[train['lotarea'] <= 25000]
train = train[train['zoning'] != 'I']
train = train[train['zoning'] != 'C']
train = train[train['zoning'] != 'A']

# %%
X = train[['saleprice','qualityindex','totalsqftcalc','yearbuilt','lotarea','lotfrontage']].copy()
X1 = train[['qualityindex','totalsqftcalc','yearbuilt','lotarea','lotfrontage']].copy()
corr = X[X.columns].corr()
corr

# %%
from sklearn.preprocessing import StandardScaler
features = ['qualityindex', 'totalsqftcalc', 'yearbuilt', 'lotarea','lotfrontage']
# Separating out the features
x = test.loc[:, features].values
# Separating out the target
y = test.loc[:,['saleprice']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal_component_1', 'principal_component_2','principal_component_3','principal_component_4','principal_component_5'])

# %%
testfinalDf = pd.concat([principalDf, test], axis = 1)

# %%
testfinalDf
# Out:
#      principal_component_1  principal_component_2  principal_component_3  \
# 0                -2.389337               0.726454               0.399535
# 1                 0.435780              -1.047237              -0.725893
# 2                 0.764211              -0.986961               0.585785
# 3                 1.243041              -0.933242              -0.400503
# 4                -0.064110              -0.608939              -0.612921
# 5                 0.297093              -0.699067              -0.465278
# 6                -2.246401               1.136959               0.125904
# 7                -0.652723              -0.345030              -0.020498
# 8                 0.726153              -0.750779              -0.311670
# 9                -0.376558               0.197917              -0.331361
# 10               -1.781970               0.010271               0.022740
# 11               -0.210034              -0.523858               0.239436
# 12                0.017031              -0.476911              -0.481012
# 13                1.858713              -0.658061               0.032528
# 14                1.439058              -1.010597              -0.236227
# 15                0.919149               0.440085               1.115565
# 16                2.374948               0.933463               3.138178
# 17                1.571354              -0.041492               0.788159
# 18               -1.856208              -0.062697               0.112935
# 19               -1.178668              -0.486213               0.517115
# 20                0.692013              -0.268826              -0.142781
# 21                1.508863              -0.847326               0.132131
# 22               -0.792822              -0.619219              -0.094521
# 23                0.922082              -0.690887              -0.337655
# 24                1.273468              -0.451006              -0.239129
# 25               -1.479742              -0.510856               0.565117
# 26               -0.803655              -0.338191              -0.040752
# 27               -0.832128              -0.323233              -0.977895
# 28                0.110398              -0.735904              -0.654041
# 29                0.940707               1.567120              -1.129568
# ..                     ...                    ...                    ...
# 696               0.302055              -0.707980               1.339471
# 697              -0.653736              -0.255321               0.496394
# 698               0.027511              -0.805306              -0.830781
# 699               1.628428              -0.864803              -0.228252
# 700               0.568712              -0.530443              -0.309618
# 701              -1.059746              -0.823901               0.296629
# 702              -0.514910              -1.079571               1.506341
# 703              -0.510705              -0.168048              -0.476744
# 704               0.143671               1.311046              -0.872260
# 705               1.097456              -0.919414              -0.309869
# 706              -0.440061               1.825977              -1.053216
# 707               0.189298              -0.833024              -0.726094
# 708               0.975838              -0.150418               0.926443
# 709              -1.352881               0.015595               0.327916
# 710               1.850985               1.207299              -1.276403
# 711              -1.485383               0.314857              -0.165266
# 712               1.727317               0.204917               2.068269
# 713              -0.195695               1.745854              -1.116837
# 714              -0.347383              -0.812740               0.676873
# 715              -1.356281              -0.532596               1.247546
# 716               1.574974               1.416785              -1.491465
# 717               1.537106              -1.005896              -0.184596
# 718              -0.871632              -0.159950               0.515416
# 719              -1.203963              -1.063000               0.935284
# 720               1.925891               1.334104              -1.160003
# 721               1.553443               1.473912              -1.057669
# 722               1.660778              -0.903831              -0.055430
# 723              -0.853895              -0.443913               0.090528
# 724              -0.046771              -0.705986               0.314829
# 725              -0.224533               2.863294               1.342728
#
#      principal_component_4  principal_component_5  index  p_saleprice  \
# 0                 1.179946               0.231206      1          NaN
# 1                 0.198199               0.701992      4          NaN
# 2                -0.932260              -0.017951      7          NaN
# 3                 0.255282              -0.183912     11          NaN
# 4                 0.679107               1.133062     13          NaN
# 5                 0.445443               0.175111     18          NaN
# 6                 2.070983              -1.073092     20          NaN
# 7                 0.299177              -0.141914     22          NaN
# 8                 0.381324               0.753050     26          NaN
# 9                 1.674892               1.162883     43          NaN
# 10                0.486367              -0.553055     44          NaN
# 11               -0.121651              -0.077266     45          NaN
# 12                0.726868              -0.121007     46          NaN
# 13                0.358035              -1.972452     52          NaN
# 14                0.008451              -0.447318     53          NaN
# 15               -4.553417               1.215583     55          NaN
# 16                0.398798               1.185954     58          NaN
# 17                0.661466              -0.912136     63          NaN
# 18                0.295768               0.148756     66          NaN
# 19               -0.612951              -0.120388     69          NaN
# 20                0.928930              -0.531989     74          NaN
# 21               -0.112913              -1.267498     81          NaN
# 22               -0.085023               0.464385     85          NaN
# 23                0.467300              -0.564818     89          NaN
# 24                0.825410              -1.502798     92          NaN
# 25               -0.768837               0.185840     93          NaN
# 26                0.293453               0.039435     97          NaN
# 27                1.271707               0.837317    101          NaN
# 28                0.544988               0.609184    102          NaN
# 29               -0.633541              -1.163022    103          NaN
# ..                     ...                    ...    ...          ...
# 696              -1.339486               0.016084   2805          NaN
# 697              -0.022365               0.472927   2806          NaN
# 698               0.582656               0.784714   2811          NaN
# 699               0.291788              -0.586295   2812          NaN
# 700               0.668081               0.313657   2817          NaN
# 701              -0.865061               0.933100   2821          NaN
# 702              -2.309800               0.755746   2822          NaN
# 703               1.101489               0.095758   2828          NaN
# 704              -1.432868               0.682993   2829          NaN
# 705               0.137157              -0.239451   2842          NaN
# 706              -0.667457              -0.712667   2846          NaN
# 707               0.456965               0.314835   2854          NaN
# 708               0.261483               0.772704   2857          NaN
# 709               0.323441              -0.415472   2861          NaN
# 710              -0.738927              -0.058855   2862          NaN
# 711               1.232066              -0.853285   2866          NaN
# 712              -0.144898               0.855033   2868          NaN
# 713              -0.589080               0.389176   2870          NaN
# 714              -1.081126              -0.416031   2873          NaN
# 715              -1.442540               0.153441   2878          NaN
# 716              -0.356028              -1.412290   2883          NaN
# 717               0.052844               0.273339   2885          NaN
# 718              -0.006309              -0.468636   2886          NaN
# 719              -1.967753               0.318863   2900          NaN
# 720              -0.702793              -1.322422   2903          NaN
# 721              -0.639441              -0.702677   2912          NaN
# 722               0.104196               0.250686   2914          NaN
# 723               0.018202               0.784014   2919          NaN
# 724              -0.402376               0.625364   2923          NaN
# 725              -1.080992               0.813928   2924          NaN
#
#      saleprice  subclass zoning        ...          miscfeature  miscval  \
# 0          NaN        30      C        ...                  NaN        0
# 1          NaN        20     FV        ...                  NaN        0
# 2          NaN        60     RL        ...                  NaN        0
# 3          NaN        20     RL        ...                  NaN        0
# 4          NaN        20     RL        ...                  NaN        0
# 5          NaN        60     RL        ...                  NaN        0
# 6          NaN        20     RM        ...                  NaN        0
# 7          NaN        20     RL        ...                  NaN        0
# 8          NaN        60     RL        ...                  NaN        0
# 9          NaN        20     RL        ...                  NaN        0
# 10         NaN        50     RM        ...                  NaN        0
# 11         NaN        20     RL        ...                  NaN        0
# 12         NaN        60     RL        ...                  NaN        0
# 13         NaN        60     RL        ...                  NaN        0
# 14         NaN        60     RL        ...                  NaN        0
# 15         NaN        70     RM        ...                  NaN        0
# 16         NaN        20     RL        ...                  NaN        0
# 17         NaN        20     RL        ...                  NaN        0
# 18         NaN        20     RL        ...                  NaN        0
# 19         NaN        50     RM        ...                  NaN        0
# 20         NaN        60     RL        ...                  NaN        0
# 21         NaN        20     RL        ...                  NaN        0
# 22         NaN        85     RL        ...                  NaN        0
# 23         NaN        60     RL        ...                  NaN        0
# 24         NaN        60     RL        ...                  NaN        0
# 25         NaN        70     RL        ...                  NaN        0
# 26         NaN        85     RL        ...                  NaN        0
# 27         NaN        20     RL        ...                  NaN        0
# 28         NaN        60     RL        ...                  NaN        0
# 29         NaN        20     RL        ...                  NaN        0
# ..         ...       ...    ...        ...                  ...      ...
# 696        NaN        50     RL        ...                  NaN        0
# 697        NaN        20     RL        ...                  NaN        0
# 698        NaN        60     FV        ...                  NaN        0
# 699        NaN        20     RL        ...                  NaN        0
# 700        NaN        60     RL        ...                  NaN        0
# 701        NaN        45     RL        ...                  NaN        0
# 702        NaN        50     RL        ...                  NaN        0
# 703        NaN        60     RL        ...                  NaN        0
# 704        NaN        80     RL        ...                  NaN        0
# 705        NaN        60     RL        ...                  NaN        0
# 706        NaN        20     RL        ...                  NaN        0
# 707        NaN        60     RL        ...                  NaN        0
# 708        NaN        20     RL        ...                  NaN        0
# 709        NaN        50     RL        ...                  NaN        0
# 710        NaN        60     RL        ...                  NaN        0
# 711        NaN        20     RL        ...                  NaN        0
# 712        NaN        20     RL        ...                  NaN        0
# 713        NaN        80     RL        ...                  NaN        0
# 714        NaN        50     RM        ...                  NaN        0
# 715        NaN        70     RM        ...                  NaN        0
# 716        NaN        60     RL        ...                  NaN        0
# 717        NaN        60     RL        ...                  NaN        0
# 718        NaN        50     RM        ...                  NaN        0
# 719        NaN        70     RM        ...                  NaN        0
# 720        NaN        60     RL        ...                  NaN        0
# 721        NaN        80     RL        ...                  NaN        0
# 722        NaN        60     RL        ...                  NaN        0
# 723        NaN        20     RL        ...                  NaN        0
# 724        NaN        20     RL        ...                  NaN        0
# 725        NaN        30     RL        ...                  NaN        0
#
#     mosold yrsold saletype salecondition qualityindex totalsqftcalc  \
# 0       10   2006       WD       Abnorml           15           729
# 1       10   2009      New       Partial           40          1836
# 2        7   2007       WD        Normal           48          2504
# 3        1   2009       WD        Normal           40          2802
# 4       10   2007      New       Partial           35          1316
# 5        4   2010       WD        Normal           35          2098
# 6       12   2008       WD       Abnorml            3          1588
# 7        7   2010       WD        Normal           30          1831
# 8        1   2006      New       Partial           40          1964
# 9        7   2006       WD       Abnorml           25          1140
# 10       6   2007       WD        Normal           21          1514
# 11       7   2008       WD        Normal           36          2028
# 12       6   2008       WD        Normal           30          2136
# 13       8   2007       WD        Normal           35          4232
# 14       6   2006       WD        Normal           42          3072
# 15       5   2007       WD        Normal           72          1772
# 16       4   2008       WD        Normal           49          2652
# 17       8   2008       WD        Normal           35          3456
# 18       7   2008       WD        Normal           25          1048
# 19       3   2007      CWD        Normal           35          1580
# 20       3   2010       WD        Normal           30          2741
# 21       7   2009       WD        Normal           40          3628
# 22       4   2007       WD        Normal           35          1387
# 23       6   2007       WD        Normal           35          2875
# 24       3   2010       WD        Normal           30          3632
# 25       3   2009       WD        Normal           36          1242
# 26       8   2006       WD        Normal           30          1642
# 27       2   2008       WD       Abnorml           25          1092
# 28       4   2009       WD        Normal           35          1728
# 29       5   2009       WD        Normal           30          3134
# ..     ...    ...      ...           ...          ...           ...
# 696      6   2006       WD        Normal           49          2280
# 697      6   2006       WD        Normal           35          1472
# 698      6   2010      Con        Normal           35          1571
# 699      4   2007       WD        Normal           40          3251
# 700      5   2008       WD        Normal           35          2153
# 701      6   2008       WD        Normal           42           984
# 702      6   2007       WD        Normal           56          1426
# 703      3   2010       WD        Normal           25          1732
# 704      6   2008       WD        Normal           40          1608
# 705      2   2006       WD        Normal           40          2767
# 706      5   2010       WD        Normal           25          2161
# 707      7   2007       WD        Normal           35          1948
# 708      4   2008       WD        Normal           42          2123
# 709     10   2008      COD       Abnorml           25          1658
# 710      2   2006       WD        Normal           40          2908
# 711     12   2006       WD       Abnorml           15          1835
# 712     11   2008       WD        Normal           49          2494
# 713      5   2007       WD        Normal           30          1601
# 714      7   2008       WD        Normal           42          2193
# 715      3   2007       WD        Normal           42          1355
# 716      6   2008       WD        Normal           30          3593
# 717      7   2006      New       Partial           45          2678
# 718      6   2008       WD        Normal           30          1944
# 719      2   2010       WD        Normal           48          1324
# 720      4   2006       WD        Normal           35          3730
# 721      8   2009       WD        Normal           35          3162
# 722      5   2007       WD        Normal           45          2758
# 723      7   2006      COD        Normal           35          1164
# 724      5   2008       WD        Normal           42          1682
# 725      8   2007       WD        Normal           35          1416
#
#     pricesqfoot Neighborhood_Group
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN
# 3           NaN                NaN
# 4           NaN                NaN
# 5           NaN                NaN
# 6           NaN                NaN
# 7           NaN                NaN
# 8           NaN                NaN
# 9           NaN                NaN
# 10          NaN                NaN
# 11          NaN                NaN
# 12          NaN                NaN
# 13          NaN                NaN
# 14          NaN                NaN
# 15          NaN                NaN
# 16          NaN                NaN
# 17          NaN                NaN
# 18          NaN                NaN
# 19          NaN                NaN
# 20          NaN                NaN
# 21          NaN                NaN
# 22          NaN                NaN
# 23          NaN                NaN
# 24          NaN                NaN
# 25          NaN                NaN
# 26          NaN                NaN
# 27          NaN                NaN
# 28          NaN                NaN
# 29          NaN                NaN
# ..          ...                ...
# 696         NaN                NaN
# 697         NaN                NaN
# 698         NaN                NaN
# 699         NaN                NaN
# 700         NaN                NaN
# 701         NaN                NaN
# 702         NaN                NaN
# 703         NaN                NaN
# 704         NaN                NaN
# 705         NaN                NaN
# 706         NaN                NaN
# 707         NaN                NaN
# 708         NaN                NaN
# 709         NaN                NaN
# 710         NaN                NaN
# 711         NaN                NaN
# 712         NaN                NaN
# 713         NaN                NaN
# 714         NaN                NaN
# 715         NaN                NaN
# 716         NaN                NaN
# 717         NaN                NaN
# 718         NaN                NaN
# 719         NaN                NaN
# 720         NaN                NaN
# 721         NaN                NaN
# 722         NaN                NaN
# 723         NaN                NaN
# 724         NaN                NaN
# 725         NaN                NaN
#
# [726 rows x 91 columns]

# %%
from sklearn.preprocessing import StandardScaler
features = ['qualityindex', 'totalsqftcalc', 'yearbuilt', 'lotarea','lotfrontage']
# Separating out the features
x = train.loc[:, features].values
# Separating out the target
y = train.loc[:,['saleprice']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal_component_1', 'principal_component_2','principal_component_3','principal_component_4','principal_component_5'])

# %%
finalDf = pd.concat([principalDf, train], axis = 1)

# %%
finalDf
# Out:
#       principal_component_1  principal_component_2  principal_component_3  \
# 0                  1.478548               1.530132              -0.512232
# 1                 -0.144652              -0.269586              -0.974131
# 2                 -2.157300              -0.029569               0.766496
# 3                  1.550189               2.244364               0.430222
# 4                 -0.176626               0.028672               0.634735
# 5                 -1.029427              -0.467810               0.857694
# 6                 -2.828152               1.933741               0.714643
# 7                 -0.974928              -0.736737              -1.239083
# 8                 -0.613330              -0.215826              -0.952284
# 9                 -1.119026              -0.659759               0.196631
# 10                 1.418241               0.667933               2.938783
# 11                -1.823114              -0.539166              -1.243951
# 12                 1.837358              -1.045115              -0.335679
# 13                 0.451618               1.449272              -0.700083
# 14                -0.784020              -0.179836              -1.277010
# 15                -1.764213               0.414231               0.003500
# 16                -1.306903              -0.425058               0.901850
# 17                -0.599489               0.622879               0.077902
# 18                -2.040230              -0.324321               0.806811
# 19                -2.120344              -0.064827              -1.612239
# 20                 1.400089               1.649293              -1.257820
# 21                -0.078364              -1.243846               1.607986
# 22                 0.413910              -0.493994              -0.797302
# 23                -0.649539              -0.105376               0.232509
# 24                -3.035792               1.015479              -0.710006
# 25                -1.176375               0.204053               0.246116
# 26                -0.469125               1.358025               0.931645
# 27                 1.633728              -1.086964              -0.318692
# 28                -0.090573              -0.381798              -0.718132
# 29                -1.043351              -0.760925              -1.697641
# ...                     ...                    ...                    ...
# 1995                    NaN                    NaN                    NaN
# 1998                    NaN                    NaN                    NaN
# 1999                    NaN                    NaN                    NaN
# 2001                    NaN                    NaN                    NaN
# 2003                    NaN                    NaN                    NaN
# 2004                    NaN                    NaN                    NaN
# 2005                    NaN                    NaN                    NaN
# 2007                    NaN                    NaN                    NaN
# 2008                    NaN                    NaN                    NaN
# 2009                    NaN                    NaN                    NaN
# 2010                    NaN                    NaN                    NaN
# 2011                    NaN                    NaN                    NaN
# 2013                    NaN                    NaN                    NaN
# 2014                    NaN                    NaN                    NaN
# 2015                    NaN                    NaN                    NaN
# 2016                    NaN                    NaN                    NaN
# 2017                    NaN                    NaN                    NaN
# 2018                    NaN                    NaN                    NaN
# 2020                    NaN                    NaN                    NaN
# 2021                    NaN                    NaN                    NaN
# 2022                    NaN                    NaN                    NaN
# 2024                    NaN                    NaN                    NaN
# 2026                    NaN                    NaN                    NaN
# 2028                    NaN                    NaN                    NaN
# 2029                    NaN                    NaN                    NaN
# 2032                    NaN                    NaN                    NaN
# 2034                    NaN                    NaN                    NaN
# 2036                    NaN                    NaN                    NaN
# 2037                    NaN                    NaN                    NaN
# 2038                    NaN                    NaN                    NaN
#
#       principal_component_4  principal_component_5  subclass zoning  \
# 0                  1.078410              -0.978536      20.0     RL
# 1                 -0.527987              -0.272409      60.0     RL
# 2                  0.417572               0.099067      45.0     RM
# 3                  0.004942               0.143842      60.0     RL
# 4                 -0.714604               0.188203      20.0     RL
# 5                  0.443852               0.618554      30.0     RL
# 6                 -2.249526               0.598054      70.0     RM
# 7                  0.382762               0.995964       NaN    NaN
# 8                 -0.332454              -0.553083       NaN    NaN
# 9                  0.651434               0.668467     160.0     RL
# 10                -2.088354               0.416075      80.0     RL
# 11                 0.631975               0.082580      50.0     RM
# 12                -0.393111               0.799909      70.0     RL
# 13                 1.574581               0.066855     160.0     RM
# 14                -0.298592              -1.034717      60.0     RL
# 15                -0.521133              -0.501976      80.0     RL
# 16                 0.551962               0.445909      20.0     RL
# 17                -1.495710               0.191340       NaN    NaN
# 18                 0.834956              -0.173766      20.0     RM
# 19                -0.071413               0.751140      40.0     RL
# 20                 0.608840               0.686746     190.0     RL
# 21                 1.235221               0.712172      30.0     RM
# 22                -0.411637              -0.574660     180.0     RM
# 23                -0.349331               0.183921      60.0     RL
# 24                -1.022157               0.583077      70.0     RM
# 25                -0.568538               0.346270      80.0     RL
# 26                -2.424489              -0.540051      20.0     RL
# 27                -0.074411              -0.504461      20.0     RL
# 28                -0.243618              -1.001229      50.0     RM
# 29                 0.588704              -0.785864       NaN    NaN
# ...                     ...                    ...       ...    ...
# 1995                    NaN                    NaN      60.0     RL
# 1998                    NaN                    NaN      60.0     RL
# 1999                    NaN                    NaN      20.0     RL
# 2001                    NaN                    NaN      60.0     FV
# 2003                    NaN                    NaN      60.0     RM
# 2004                    NaN                    NaN      85.0     RL
# 2005                    NaN                    NaN      50.0     RM
# 2007                    NaN                    NaN      70.0     RM
# 2008                    NaN                    NaN      70.0     RM
# 2009                    NaN                    NaN     120.0     RL
# 2010                    NaN                    NaN      50.0     RL
# 2011                    NaN                    NaN      30.0     RM
# 2013                    NaN                    NaN      90.0     RL
# 2014                    NaN                    NaN      20.0     RL
# 2015                    NaN                    NaN      20.0     RL
# 2016                    NaN                    NaN      20.0     RL
# 2017                    NaN                    NaN      60.0     RL
# 2018                    NaN                    NaN      20.0     RL
# 2020                    NaN                    NaN      20.0     RL
# 2021                    NaN                    NaN      20.0     RL
# 2022                    NaN                    NaN     160.0     RM
# 2024                    NaN                    NaN      80.0     RL
# 2026                    NaN                    NaN      20.0     RL
# 2028                    NaN                    NaN      20.0     RL
# 2029                    NaN                    NaN      30.0     RM
# 2032                    NaN                    NaN      20.0     RL
# 2034                    NaN                    NaN      85.0     RL
# 2036                    NaN                    NaN     190.0     RM
# 2037                    NaN                    NaN      20.0     RL
# 2038                    NaN                    NaN      90.0     RL
#
#       lotfrontage  lotarea street     ...     miscval mosold  yrsold saletype  \
# 0         10000.0  11838.0   Pave     ...         0.0    6.0  2009.0       WD
# 1            70.0   8304.0   Pave     ...         0.0    7.0  2006.0       WD
# 2            58.0   6380.0   Pave     ...         0.0    8.0  2006.0       WD
# 3         10000.0  14803.0   Pave     ...         0.0    6.0  2006.0       WD
# 4            91.0  11375.0   Pave     ...         0.0   10.0  2007.0       WD
# 5            55.0   7111.0   Pave     ...         0.0    7.0  2008.0       WD
# 6            60.0  11340.0   Pave     ...         0.0   11.0  2008.0      Con
# 7             NaN      NaN    NaN     ...         NaN    NaN     NaN      NaN
# 8             NaN      NaN    NaN     ...         NaN    NaN     NaN      NaN
# 9            24.0   2308.0   Pave     ...         0.0    6.0  2009.0       WD
# 10           62.0   7706.0   Pave     ...       700.0    8.0  2009.0       WD
# 11           50.0   5000.0   Pave     ...         0.0    5.0  2008.0       WD
# 12          144.0  21384.0   Pave     ...         0.0    5.0  2009.0       WD
# 13           21.0   2058.0   Pave     ...         0.0   12.0  2007.0       WD
# 14           92.0  10120.0   Pave     ...         0.0   12.0  2006.0       WD
# 15        10000.0   7176.0   Pave     ...         0.0    7.0  2006.0       WD
# 16           63.0   7500.0   Pave     ...         0.0    8.0  2009.0       WD
# 17            NaN      NaN    NaN     ...         NaN    NaN     NaN      NaN
# 18           52.0   8626.0   Pave     ...         0.0    5.0  2007.0       WD
# 19           55.0   6854.0   Pave     ...         0.0    8.0  2007.0       WD
# 20           75.0  11625.0   Pave     ...         0.0    4.0  2010.0       WD
# 21           50.0   6000.0   Pave     ...         0.0    7.0  2008.0       WD
# 22           21.0   1596.0   Pave     ...         0.0   11.0  2009.0       WD
# 23        10000.0   8658.0   Pave     ...         0.0    4.0  2006.0       WD
# 24           47.0   7755.0   Pave     ...         0.0    5.0  2007.0       WD
# 25           73.0   9590.0   Pave     ...         0.0    5.0  2007.0       WD
# 26           72.0   9000.0   Pave     ...         0.0    5.0  2008.0       WD
# 27           50.0   5000.0   Pave     ...         0.0    4.0  2007.0       WD
# 28           50.0   8635.0   Pave     ...         0.0    1.0  2008.0       WD
# 29            NaN      NaN    NaN     ...         NaN    NaN     NaN      NaN
# ...           ...      ...    ...     ...         ...    ...     ...      ...
# 1995         59.0   9649.0   Pave     ...         0.0    5.0  2007.0       WD
# 1998      10000.0   7861.0   Pave     ...         0.0    6.0  2006.0       WD
# 1999         72.0   8872.0   Pave     ...         0.0   12.0  2008.0       WD
# 2001      10000.0   8010.0   Pave     ...         0.0    8.0  2007.0       WD
# 2003         57.0   8094.0   Pave     ...      1000.0    9.0  2008.0       WD
# 2004      10000.0   9101.0   Pave     ...         0.0    7.0  2009.0       WD
# 2005         60.0   9600.0   Pave     ...         0.0    5.0  2006.0       WD
# 2007         42.0   7614.0   Pave     ...         0.0    3.0  2006.0       WD
# 2008         57.0   6406.0   Pave     ...         0.0   10.0  2009.0       WD
# 2009         34.0   5122.0   Pave     ...         0.0    3.0  2009.0       WD
# 2010      10000.0  15660.0   Pave     ...         0.0    5.0  2008.0       WD
# 2011         60.0   8520.0   Pave     ...         0.0    2.0  2009.0       WD
# 2013         75.0  10125.0   Pave     ...         0.0    8.0  2009.0      COD
# 2014         65.0   8125.0   Pave     ...         0.0    7.0  2008.0       WD
# 2015      10000.0   9790.0   Pave     ...         0.0    9.0  2009.0       WD
# 2016        124.0  16158.0   Pave     ...         0.0    6.0  2009.0       WD
# 2017         90.0  14670.0   Pave     ...         0.0    8.0  2008.0       WD
# 2018         63.0  13072.0   Pave     ...         0.0    6.0  2008.0       WD
# 2020         79.0  10240.0   Pave     ...         0.0    5.0  2006.0       WD
# 2021         70.0  10552.0   Pave     ...         0.0    4.0  2010.0       WD
# 2022         21.0   1890.0   Pave     ...         0.0    7.0  2006.0       WD
# 2024      10000.0  10395.0   Pave     ...       500.0    7.0  2007.0       WD
# 2026         70.0   9100.0   Pave     ...       400.0    8.0  2008.0       WD
# 2028         70.0   8750.0   Pave     ...         0.0    8.0  2009.0       WD
# 2029         51.0   6120.0   Pave     ...         0.0   11.0  2009.0       WD
# 2032         65.0  10816.0   Pave     ...         0.0   11.0  2009.0       WD
# 2034         75.0  11235.0   Pave     ...         0.0   11.0  2007.0       WD
# 2036         60.0  10800.0   Pave     ...         0.0    4.0  2008.0       WD
# 2037         65.0   7800.0   Pave     ...         0.0    6.0  2010.0       WD
# 2038      10000.0   7939.0   Pave     ...         0.0   10.0  2009.0       WD
#
#      salecondition saleprice   index qualityindex totalsqftcalc pricesqfoot
# 0           Normal  236500.0     2.0         40.0        1788.0  132.270694
# 1           Normal  187000.0     3.0         30.0        1837.0  101.796407
# 2           Normal  113000.0     5.0         30.0        1048.0  107.824427
# 3           Normal  190000.0     6.0         30.0        2409.0   78.870901
# 4           Normal  150000.0     8.0         30.0        2035.0   73.710074
# 5           Normal  138000.0     9.0         35.0        1822.0   75.740944
# 6           Normal   55000.0    10.0          2.0        1086.0   50.644567
# 7              NaN       NaN     NaN          NaN           NaN         NaN
# 8              NaN       NaN     NaN          NaN           NaN         NaN
# 9           Normal  147000.0    16.0         30.0        2074.0   70.877531
# 10          Normal  131250.0    17.0         30.0        1475.0   88.983051
# 11          Normal  124000.0    19.0         35.0        1810.0   68.508287
# 12          Normal  223500.0    21.0         30.0        2885.0   77.469671
# 13          Normal  113700.0    24.0         30.0        1218.0   93.349754
# 14          Normal  290000.0    25.0         40.0        3266.0   88.793631
# 15          Normal  160500.0    27.0         36.0        1834.0   87.513631
# 16          Normal  143500.0    28.0         30.0        1158.0  123.920553
# 17             NaN       NaN     NaN          NaN           NaN         NaN
# 18          Normal  104500.0    30.0         24.0         968.0  107.954545
# 19          Normal  136500.0    31.0         35.0        1604.0   85.099751
# 20          Normal  131500.0    32.0         20.0        1880.0   69.946809
# 21          Normal  119000.0    33.0         35.0         949.0  125.395153
# 22          Normal   91000.0    34.0         20.0        1450.0   62.758621
# 23          Normal  215000.0    35.0         30.0        2621.0   82.029760
# 24          Normal  200000.0    36.0         48.0        2264.0   88.339223
# 25          Normal  187500.0    37.0         35.0        1932.0   97.049689
# 26          Normal  139000.0    38.0         30.0        1812.0   76.710817
# 27          Normal   64500.0    39.0          9.0         965.0   66.839378
# 28          Normal  127000.0    40.0         25.0        1662.0   76.413959
# 29             NaN       NaN     NaN          NaN           NaN         NaN
# ...            ...       ...     ...          ...           ...         ...
# 1995        Normal  185000.0  2872.0         30.0        1644.0  112.530414
# 1998        Normal  183200.0  2876.0         30.0        1966.0   93.184130
# 1999        Normal  147000.0  2877.0         40.0        1507.0   97.544791
# 2001        Normal  301000.0  2880.0         40.0        3012.0   99.933599
# 2003        Normal  160000.0  2884.0         48.0        2180.0   73.394495
# 2004        Normal  165500.0  2887.0         30.0        2207.0   74.988672
# 2005        Normal  135000.0  2888.0         30.0        1944.0   69.444444
# 2007        Normal   96900.0  2890.0         15.0        1376.0   70.421512
# 2008        Normal  150000.0  2891.0         30.0        1979.0   75.795856
# 2009        Normal  184500.0  2892.0         30.0        2187.0   84.362140
# 2010        Normal  311500.0  2893.0         63.0        2295.0  135.729847
# 2011        Normal   99500.0  2894.0         40.0         792.0  125.631313
# 2013        Normal  126000.0  2896.0         25.0        1734.0   72.664360
# 2014        Normal  135000.0  2897.0         35.0        1641.0   82.266910
# 2015        Normal  161500.0  2898.0         30.0        2223.0   72.649573
# 2016        Normal  260000.0  2901.0         35.0        2804.0   92.724679
# 2017        Normal  227000.0  2902.0         42.0        2563.0   88.568084
# 2018        Normal  146000.0  2904.0         30.0        1255.0  116.334661
# 2020        Normal  207500.0  2907.0         36.0        3372.0   61.536180
# 2021        Normal  165500.0  2908.0         25.0        2718.0   60.890361
# 2022        Normal  116000.0  2909.0         42.0        1312.0   88.414634
# 2024        Normal  148000.0  2911.0         36.0        1637.0   90.409285
# 2026        Normal  128000.0  2915.0         25.0        1836.0   69.716776
# 2028        Normal  210000.0  2917.0         35.0        2528.0   83.069620
# 2029        Normal  105000.0  2918.0         35.0        1084.0   96.863469
# 2032        Normal  332000.0  2922.0         45.0        2824.0  117.563739
# 2034        Normal  158450.0  2926.0         25.0        2237.0   70.831471
# 2036        Normal  163000.0  2928.0         42.0        1912.0   85.251046
# 2037        Normal  137900.0  2929.0         35.0        1606.0   85.865504
# 2038        Normal  269500.0  2930.0         35.0        3607.0   74.715830
#
# [1966 rows x 89 columns]

# %%
model1 = smf.ols(formula='saleprice ~ qualityindex+totalsqftcalc+C(lotconfig)+C(neighborhood)+C(housestyle)+yearbuilt+C(roofstyle)+C(heating)', data=train).fit()
model1.summary()

# %%
predictions_1 = model1.fittedvalues
predictions_1.head()

# %%
test_predictions_1 = model1.predict(test)
d = {'p_saleprice': test_predictions_1}
df1 = test[['index']]
df2=pd.DataFrame(data=d)
Strouse_TestPredictions_1 = pd.concat([df1,df2],axis = 1, join_axes=[df1.index])
Strouse_TestPredictions_1.head()

# %%
Strouse_TestPredictions_1.to_csv('logan_strouse_HW2_MODEL_1_NBGROUP.csv')

# %%
PCA_MODEL = smf.ols(formula='saleprice ~principal_component_1', data=finalDf).fit()
PCA_MODEL.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.498
# Date:                Sun, 10 Mar 2019   Prob (F-statistic):              0.221
# Time:                        17:30:05   Log-Likelihood:                -16579.
# No. Observations:                1324   AIC:                         3.316e+04
# Df Residuals:                    1322   BIC:                         3.317e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              1.732e+05   1825.521     94.901      0.000     1.7e+05    1.77e+05
# principal_component_1 -1686.9495   1378.449     -1.224      0.221   -4391.136    1017.237
# ==============================================================================
# Omnibus:                      334.175   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              785.609
# Skew:                           1.371   Prob(JB):                    2.55e-171
# Kurtosis:                       5.594   Cond. No.                         1.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
predictions_1 = PCA_MODEL.fittedvalues
predictions_1.head()

# %%
test_predictions_1 = PCA_MODEL.predict(testfinalDf)
d = {'p_saleprice': test_predictions_1}
df1 = test[['index']]
df2=pd.DataFrame(data=d)
Strouse_TestPredictions_1 = pd.concat([df1,df2],axis = 1, join_axes=[df1.index])
Strouse_TestPredictions_1.head()

# %%
Strouse_TestPredictions_1.to_csv('logan_strouse_HW4_PCA_1_NBGROUP.csv')

# %%
neighborhood_predictions = model1.fittedvalues
neighborhood_predictions.head()
tr = {'p_saleprice': neighborhood_predictions}
df1 = train[['index','saleprice','neighborhood','totalsqftcalc']]
df2=pd.DataFrame(data=tr)
n_file = pd.concat([df1,df2],axis = 1, join_axes=[df1.index])

n_file['residual'] = (n_file.saleprice-n_file.p_saleprice)
n_file['actual_ppsf'] = (n_file.saleprice/n_file.totalsqftcalc)
n_file['predicted_ppsf'] = (n_file.p_saleprice/n_file.totalsqftcalc)
compare = n_file[['neighborhood','actual_ppsf','predicted_ppsf']]
compare.head()

# %%
group1 = ['GrnHill', 'Blmngtn', 'NridgHt','Somerst','StoneBr','Timber','Gilbert','CollgCr','NoRidge']
group2 = ['Crawfor','Blueste','SawyerW','Greens','BrkSide','Veenker','Mitchel','IDOTRR','OldTown']
group3 = ['ClearCr','NWAmes','NPkVill','NAmes','Sawyer','Edwards','BrDale','SWISU','MeadowV']
c_2 = compare.copy()
#c_2['Neighborhood_Group'] = c_2['neighborhood'].copy()
#c_2['Neighborhood_Group'] = c_2['neighborhood'].isin(group1).astype('int64')
#c_2['Neighborhood_Group'] = c_2['neighborhood'].isin(group2).astype('int64',copy=False)
#c_2.loc[c_2.Neighborhood_Group == 'CollgCr'] = 1
#c_2
conditions = [
    (c_2['neighborhood'].isin(group1)),
    (c_2['neighborhood'].isin(group2)),
    (c_2['neighborhood'].isin(group3))]
choices = ['1', '2', '3']
c_2['Neighborhood_Group'] = np.select(conditions, choices, default='NA')
c_2

# %%
import seaborn as sns
ax = sns.boxplot(x="neighborhood", y="residual", data=n_file)
ax.set_title("Residual by Neighborhood")
ax.set_ylabel("Residual")
ax.set_xlabel("Neighborhood")
plt.xticks(rotation=75)
plt.show()

# %%
grouping = c_2[['neighborhood','actual_ppsf','predicted_ppsf','Neighborhood_Group']].groupby('neighborhood').mean()
grouping_sorted = grouping.sort_values(by=['actual_ppsf'], ascending=[False])
grouping_sorted
#neighborhoods sorted by actual ppsf

# %%
grouping_sorted_1 = grouping_sorted.reset_index()

# %%
grouping_sorted_1.iloc[1:]

# %%
group1 = ['GrnHill', 'Blmngtn', 'NridgHt','Somerst','StoneBr','Timber','Gilbert','CollgCr','NoRidge']
group2 = ['Crawfor','Blueste','SawyerW','Greens','BrkSide','Veenker','Mitchel','IDOTRR','OldTown']
group3 = ['ClearCr','NWAmes','NPkVill','NAmes','Sawyer','Edwards','BrDale','SWISU','MeadowV']
conditions = [
    (grouping_sorted_1['neighborhood'].isin(group1)),
    (grouping_sorted_1['neighborhood'].isin(group2)),
    (grouping_sorted_1['neighborhood'].isin(group3))]
choices = ['1', '2', '3']
grouping_sorted_1['Neighborhood_Group'] = np.select(conditions, choices, default='NA')
print(grouping_sorted_1)
